# %% [markdown]
# #MY FIRST JUPYTER NOTEBOOK FOR IBM DATA SCIENCE

# %% [markdown]
# **RAGHU MADHAV TIWARI**
# I am currently a college student and I want to become a Data Scientist.

# %% [markdown]
# *I am interested in Data Science as solving problem fascinates me. Also I love mathematics and working with computers, so Data science provides me with an oppurtunity to work with the things I love.*

# %% [markdown]
# ###My code in the next cell multiplies two numbers(5 and 4) to give 20.

# %%
5*4
# Out:
# 20

# %% [markdown]
# ###THINGS TO IMPROVE SELF-
# 1. STUDY
# 2. EXERCISE
# 3. MEDITATION
# ***
# ###THINGS I AM CURRENTLY DOING-
# * Netflix
# * PUBG
# * LITTLE BIT STUDY
# ___
# ###This is a a table
#
# heading1|heading2|heading3
# ---|---|---
# item1|item2|item3
# this|is|2nd row
# this|is|~~4th~~ 3rd row
#
#
#
# ***
# [I USED THIS LINK TO PREPARE  ](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#links)
# ***
# INLINE STYLE IMAGE:
# ![alt text](https://cdn.vox-cdn.com/thumbor/Pkmq1nm3skO0-j693JTMd7RL0Zk=/0x0:2012x1341/1200x800/filters:focal(0x0:2012x1341)/cdn.vox-cdn.com/uploads/chorus_image/image/47070706/google2.0.0.jpg "Google")
# ***
